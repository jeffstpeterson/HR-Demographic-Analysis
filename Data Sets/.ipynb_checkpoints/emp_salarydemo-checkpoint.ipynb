# %%
import pandas as pd
# settings to display all columns
pd.set_option("display.max_columns", None)
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

data_file = "Sql Data/employee_salary_demographic.csv"

emp_salarydemo = pd.read_csv(data_file)
emp_salarydemo

#code for csv DELETE when done

# hourly_demog.to_csv("Tableau csv/hourly_demog.csv", index=False, header=True)
# Out:
#      employee_no              position     department  status flsa_status  \
# 0     1301052347  Sr. Network Engineer          IT/IS  Active      Exempt
# 1     1108028108  Sr. Network Engineer          IT/IS  Active      Exempt
# 2     1411071312  Sr. Network Engineer          IT/IS  Active      Exempt
# 3     1308060959  Sr. Network Engineer          IT/IS  Active      Exempt
# 4     1308060959  Sr. Network Engineer          IT/IS  Active      Exempt
# ..           ...                   ...            ...     ...         ...
# 239   1103024456          Accountant I  Admin Offices  Active      Exempt
# 240   1103024456          Accountant I  Admin Offices  Active      Exempt
# 241   1106026572          Accountant I  Admin Offices  Active      Exempt
# 242   1106026572          Accountant I  Admin Offices  Active      Exempt
# 243   1302053333          Accountant I  Admin Offices  Active      Exempt
#
#     post_education                         school                  race_desc  \
# ...

# %%
emp_salarydemo.drop_duplicates(subset=['employee_no'], keep='first', inplace=True)
emp_salarydemo
# Out:
#      employee_no              position     department  status flsa_status  \
# 0     1301052347  Sr. Network Engineer          IT/IS  Active      Exempt
# 1     1108028108  Sr. Network Engineer          IT/IS  Active      Exempt
# 2     1411071312  Sr. Network Engineer          IT/IS  Active      Exempt
# 3     1308060959  Sr. Network Engineer          IT/IS  Active      Exempt
# 8      904013591  Sr. Network Engineer          IT/IS  Active      Exempt
# ..           ...                   ...            ...     ...         ...
# 186   1203032099    Area Sales Manager          Sales  Active      Exempt
# 187   1411071302    Area Sales Manager          Sales  Active      Exempt
# 235   1302053333          Accountant I  Admin Offices  Active      Exempt
# 236   1103024456          Accountant I  Admin Offices  Active      Exempt
# 238   1106026572          Accountant I  Admin Offices  Active      Exempt
#
#     post_education                              school  \
# ...

# %%
emp_salarydemo.drop(['employee_no', 'status', 'flsa_status','state', 'zip'], axis=1)
# Out:
#                  position     department post_education  \
# 0    Sr. Network Engineer          IT/IS      Bachelors
# 1    Sr. Network Engineer          IT/IS      Bachelors
# 2    Sr. Network Engineer          IT/IS      Bachelors
# 3    Sr. Network Engineer          IT/IS     Associates
# 8    Sr. Network Engineer          IT/IS      Bachelors
# ..                    ...            ...            ...
# 186    Area Sales Manager          Sales     Associates
# 187    Area Sales Manager          Sales     Associates
# 235          Accountant I  Admin Offices      Bachelors
# 236          Accountant I  Admin Offices      Bachelors
# 238          Accountant I  Admin Offices     Associates
#
#                                  school                  race_desc  age  \
# 0                   New York University                      Asian   39
# 1                        Boston College                      White   31
# 2         Pennsylvania State University                      White   66
# ...

# %%
emp_salarydemo.to_csv("Tableau csv/emp_salarydemo.csv", index=False, header=True)
