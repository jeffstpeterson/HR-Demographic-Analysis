# %%
#import dependencies

import pandas as pd
# settings to display all columns
pd.set_option("display.max_columns", None)
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

data_file = "Sql Data/terminated_employees.csv"

term_emp = pd.read_csv(data_file)
term_emp
# Out:
#      employee_no                  position            department  \
# 0      711007713  Administrative Assistant         Admin Offices
# 1      711007713  Administrative Assistant         Admin Offices
# 2     1001167253        Area Sales Manager                 Sales
# 3     1504073368        Area Sales Manager                 Sales
# 4     1504073368        Area Sales Manager                 Sales
# ..           ...                       ...                   ...
# 270   1401064670         Software Engineer  Software Engineering
# 271   1401064670         Software Engineer  Software Engineering
# 272   1412071562                   Sr. DBA                 IT/IS
# 273   1412071562                   Sr. DBA                 IT/IS
# 274   1412071562                   Sr. DBA                 IT/IS
#
#                      status flsa_status        manager_name  \
# 0    Voluntarily Terminated  Non Exempt  Brandon R. LeBlanc
# 1    Voluntarily Terminated  Non Exempt  Brandon R. LeBlanc
# ...

# %%
term_emp.drop_duplicates(subset=['employee_no'], keep='first', inplace=True)
term_emp
# Out:
#      employee_no                  position            department  \
# 0      711007713  Administrative Assistant         Admin Offices
# 2     1001167253        Area Sales Manager                 Sales
# 3     1504073368        Area Sales Manager                 Sales
# 7     1102023965    Database Administrator                 IT/IS
# 9     1111030148    Database Administrator                 IT/IS
# ..           ...                       ...                   ...
# 262   1206044851   Production Technician I     Production
# 263   1001450968   Production Technician I     Production
# 267   1104025243   Production Technician I     Production
# 269   1401064670         Software Engineer  Software Engineering
# 272   1412071562                   Sr. DBA                 IT/IS
#
#                      status flsa_status        manager_name  \
# 0    Voluntarily Terminated  Non Exempt  Brandon R. LeBlanc
# 2    Voluntarily Terminated      Exempt          John Smith
# ...

# %%
term_emp.drop(['employee_no', 'term_date'], axis=1)
# Out:
#                      position            department                  status  \
# 0    Administrative Assistant         Admin Offices  Voluntarily Terminated
# 2          Area Sales Manager                 Sales  Voluntarily Terminated
# 3          Area Sales Manager                 Sales  Voluntarily Terminated
# 7      Database Administrator                 IT/IS  Voluntarily Terminated
# 9      Database Administrator                 IT/IS  Voluntarily Terminated
# ..                        ...                   ...                     ...
# 262   Production Technician I     Production           Terminated for Cause
# 263   Production Technician I     Production           Terminated for Cause
# 267   Production Technician I     Production           Terminated for Cause
# 269         Software Engineer  Software Engineering    Terminated for Cause
# 272                   Sr. DBA                 IT/IS    Terminated for Cause
#
# ...

# %%
term_emp.to_csv("Tableau csv/term_emp.csv", index=False, header=True)
